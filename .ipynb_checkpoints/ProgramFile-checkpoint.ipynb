# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_json("data.json")
latest = pd.read_json("latest-rates.json")
df = pd.DataFrame(data)
print(df)
# Out:
#                                                         rates   start_at base  \
# 2019-01-02  {'CAD': 1.5547, 'HKD': 8.9294, 'ISK': 133.4, '... 2019-01-01  EUR
# 2019-01-03  {'CAD': 1.5392000000000001, 'HKD': 8.8884, 'IS... 2019-01-01  EUR
# 2019-01-04  {'CAD': 1.5328, 'HKD': 8.9325, 'ISK': 134.0, '... 2019-01-01  EUR
# 2019-01-07  {'CAD': 1.5281, 'HKD': 8.9677, 'ISK': 135.2, '... 2019-01-01  EUR
# 2019-01-08  {'CAD': 1.5208, 'HKD': 8.9671, 'ISK': 136.1, '... 2019-01-01  EUR
# ...                                                       ...        ...  ...
# 2019-12-23  {'CAD': 1.4577, 'HKD': 8.6232, 'ISK': 135.4, '... 2019-01-01  EUR
# 2019-12-24  {'CAD': 1.4582, 'HKD': 8.629, 'ISK': 135.6, 'P... 2019-01-01  EUR
# 2019-12-27  {'CAD': 1.4592, 'HKD': 8.6845, 'ISK': 135.6, '... 2019-01-01  EUR
# 2019-12-30  {'CAD': 1.4621, 'HKD': 8.7133, 'ISK': 135.8, '... 2019-01-01  EUR
# 2019-12-31  {'CAD': 1.4598, 'HKD': 8.7473, 'ISK': 135.8, '... 2019-01-01  EUR
#
#                end_at
# ...

# %%
print(data['rates'])
# Out:
# 2019-01-02    {'CAD': 1.5547, 'HKD': 8.9294, 'ISK': 133.4, '...
# 2019-01-03    {'CAD': 1.5392000000000001, 'HKD': 8.8884, 'IS...
# 2019-01-04    {'CAD': 1.5328, 'HKD': 8.9325, 'ISK': 134.0, '...
# 2019-01-07    {'CAD': 1.5281, 'HKD': 8.9677, 'ISK': 135.2, '...
# 2019-01-08    {'CAD': 1.5208, 'HKD': 8.9671, 'ISK': 136.1, '...
#                                     ...
# 2019-12-23    {'CAD': 1.4577, 'HKD': 8.6232, 'ISK': 135.4, '...
# 2019-12-24    {'CAD': 1.4582, 'HKD': 8.629, 'ISK': 135.6, 'P...
# 2019-12-27    {'CAD': 1.4592, 'HKD': 8.6845, 'ISK': 135.6, '...
# 2019-12-30    {'CAD': 1.4621, 'HKD': 8.7133, 'ISK': 135.8, '...
# 2019-12-31    {'CAD': 1.4598, 'HKD': 8.7473, 'ISK': 135.8, '...
# Name: rates, Length: 255, dtype: object

# %%
########### Task 1 INR vs EUR from 1 Jan 2019 to 31 Jan 2019 ########################

val = ''

INR = []
date = []

dx = 1

for dx in range(32):
    if(dx < 10):
        val = '0' + str(dx)
        print(val)
    else:
        val = str(dx)
        print(val)
        
    try:
        inr = df['rates']['2019-01-'+val]['INR']
        INR.append(inr)
        date.append('2019-01-'+val)
    except:
        print("Exception Executed")

print("\n\n")
print("1 Euro to INR:\n")
for i in INR:
    print(i)
    
print("\n\n")
print("Dates:\n")
for i in date:
    print(i)
# Out:
# 00
# Exception Executed
# 01
# Exception Executed
# 02
# Exception Executed
# 03
# Exception Executed
# 04
# Exception Executed
# 05
# Exception Executed
# 06
# Exception Executed
# 07
# Exception Executed
# 08
# Exception Executed
# 09
# Exception Executed
# 10
# Exception Executed
# 11
# Exception Executed
# 12
# Exception Executed
# 13
# Exception Executed
# 14
# Exception Executed
# 15
# Exception Executed
# 16
# Exception Executed
# 17
# Exception Executed
# 18
# Exception Executed
# 19
# Exception Executed
# 20
# Exception Executed
# 21
# Exception Executed
# 22
# Exception Executed
# 23
# Exception Executed
# 24
# Exception Executed
# 25
# Exception Executed
# 26
# Exception Executed
# 27
# Exception Executed
# 28
# Exception Executed
# 29
# Exception Executed
# 30
# Exception Executed
# 31
# Exception Executed
#
#
#
# 1 Euro to INR:
#
# 79.9855
# 79.608
# 79.4315
# 79.6895
# 80.245
# 80.6365
# 81.2005
# 81.3475
# 81.2195
# 81.231
# 81.0055
# 80.9765
# 81.0875
# 80.9335
# ...

# %%
x1= date
y1 = INR

plt.figure(figsize=(20,10))
plt.xticks(rotation=90)

plt.xlabel("Dates",fontsize=10)
plt.ylabel("INR Rate",fontsize=10)

plt.title("INR vs EUR from 2019-01-01 to 2019-01-31")

plt.plot(x1,y1,marker="*",label="INR")

plt.legend()
plt.show()

# %%
############################ Task 2 INR and GBP vs EUR from 1st january 2019 to 31st january 2019 to ##########################

val2 = ''
GBP = []
i=1
for i in range(32):
    if i < 10:
        val2 = '0' + str(i)
    else:
        val2 = str(i)
        
    try:
        gbp = df['rates']['2019-01-'+val2]['GBP']
        GBP.append(gbp)
    except:
        print("Exception Executed")
    
i=0
for i in GBP:
    print(i)
# Out:
# Exception Executed
# Exception Executed
# Exception Executed
# Exception Executed
# Exception Executed
# Exception Executed
# Exception Executed
# Exception Executed
# Exception Executed
# Exception Executed
# 0.9016500000000001
# 0.90312
# 0.8998800000000001
# 0.8972
# 0.8974300000000001
# 0.8991300000000001
# 0.9042300000000001
# 0.9001500000000001
# 0.89263
# 0.8902500000000001
# 0.8859
# 0.8826
# 0.8812500000000001
# 0.8830300000000001
# 0.88
# 0.8721300000000001
# 0.8708500000000001
# 0.8658
# 0.8688800000000001
# 0.8673500000000001
# 0.87341
# 0.8757800000000001

# %%
x2 = date
y2 = INR
y3 = GBP

plt.figure(figsize=(20,10))
plt.xticks(rotation=90)

plt.title("INR and GBP vs EUR from 2019-01-01 to 2019-01-31")
plt.xlabel("Dates")
plt.ylabel("Rates")

plt.plot(x2,y2,marker="*",label="INR rate")
plt.plot(x2,y3,marker="o",label="GBP rate")

plt.legend()
plt.show()
